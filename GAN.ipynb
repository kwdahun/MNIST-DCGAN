# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import numpy as np
from matplotlib import pyplot as plt
import torchvision.utils as utils

device = "cuda" if torch.cuda.is_available() else "cpu"

transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))]
)

train_dataset = datasets.MNIST(
    root="./mnist", train=True, download=True, transform=transform
)

test_dataset = datasets.MNIST(
    root="./mnist", train=False, download=True, transform=transform
)

train_loader = DataLoader(
    dataset=train_dataset, batch_size=64, shuffle=True, drop_last=True
)
test_loader = DataLoader(
    dataset=test_dataset, batch_size=1000, shuffle=False, drop_last=True
)

# %%
class Discriminator(nn.Module):
    def __init__(self, width, height, filter_size, input_channel):
        super(Discriminator, self).__init__()

        # (i + 2p - k)/s + 1
        self.nets = nn.Sequential(
            nn.Conv2d(input_channel, filter_size, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(filter_size, filter_size * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(filter_size * 2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(filter_size * 2, filter_size * 4, 3, 2, 1, bias=False),
            nn.BatchNorm2d(filter_size * 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.3),
            nn.Conv2d(filter_size * 4, 1, 4, 1, 0, bias=False),
            nn.Sigmoid(),
        )

    def forward(self, x):
        x = self.nets(x)
        x = x.view(-1, 1)

        return x

# %%
class Generator(nn.Module):
    def __init__(self, width, height, latent_size, filter_size, output_channel):
        super(Generator, self).__init__()

        self.latent_size = latent_size

        self.nets = nn.Sequential(
            # Kernel, Stride, Padding o=(i−1)∗s+k−2p
            nn.ConvTranspose2d(latent_size, filter_size * 4, 4, 1, 0, bias=False),
            nn.BatchNorm2d(filter_size * 4),
            nn.ReLU(True),
            # 4x4
            nn.ConvTranspose2d(filter_size * 4, filter_size * 2, 3, 2, 1, bias=False),
            nn.BatchNorm2d(filter_size * 2),
            nn.ReLU(True),
            # 7x7
            nn.ConvTranspose2d(filter_size * 2, filter_size, 4, 2, 1, bias=False),
            nn.BatchNorm2d(filter_size),
            nn.ReLU(True),
            # 14x14
            nn.ConvTranspose2d(filter_size, output_channel, 4, 2, 1, bias=False),
            nn.Tanh(),
        )

    def forward(self, z):
        x = self.nets(z)

        return x

# %%
class GAN(nn.Module):
    def __init__(
        self,
        width,
        height,
        latent_size,
        device="cuda",
    ):
        super(GAN, self).__init__()
        self.generator = Generator(width, height, latent_size, 64, 1).to(device)
        self.discriminator = Discriminator(width, height, 32, 1).to(device)

    def generate(self, batch_size):
        z = torch.randn(batch_size, self.generator.latent_size, 1, 1).to(device)
        return self.generator(z)

    def discriminate(self, x):
        return self.discriminator(x)

    def forward(self, batch_size):
        fake_data = self.generate(batch_size)
        disc_fake_data = self.discriminate(fake_data)
        return fake_data, disc_fake_data

# %%
LATENT_SIZE = 100
LR = 3e-4

gan = GAN(28, 28, LATENT_SIZE).to(device)

loss = nn.BCELoss()

optim_gen = optim.Adam(gan.generator.parameters(), lr=LR, betas=(0.5, 0.999))
optim_dis = optim.Adam(gan.discriminator.parameters(), lr=LR, betas=(0.5, 0.999))

# %%
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime

run_id = datetime.now().strftime("%Y%m%d-%H%M%S")
writer = SummaryWriter(f"runs/gan_training_{run_id}")

EPOCHS = 100
BATCH_SIZE = 64

REAL_LABELS = torch.ones(BATCH_SIZE, 1).to(device)
FAKE_LABELS = torch.zeros(BATCH_SIZE, 1).to(device)


for epoch in range(1, EPOCHS + 1):
    total_loss_dis = 0
    total_accuracy = 0
    total_loss_gen = 0
    batches = 0

    for i, (real_images, _) in enumerate(train_loader):
        batches += 1

        # 장치 이동
        real_images = real_images.to(device)

        # 판별기 학습
        optim_dis.zero_grad()
        outputs = gan.discriminate(real_images)
        loss_real = loss(outputs, REAL_LABELS)
        accuracy_real = torch.where(outputs > 0.5, 1.0, 0.0).mean()

        fake_images = gan.generate(BATCH_SIZE)
        outputs = gan.discriminate(fake_images.detach())
        loss_fake = loss(outputs, FAKE_LABELS)
        accuracy_fake = torch.where(outputs < 0.5, 1.0, 0.0).mean()

        loss_dis = loss_real + loss_fake

        loss_dis.backward()
        optim_dis.step()
        accuracy = (accuracy_real + accuracy_fake) / 2

        # 생성기 학습
        optim_gen.zero_grad()
        fake_images = gan.generate(BATCH_SIZE)
        outputs = gan.discriminate(fake_images)
        loss_gen = loss(outputs, REAL_LABELS)
        loss_gen.backward()
        optim_gen.step()

        # 손실과 정확도 누적
        total_loss_dis += loss_dis.item()
        total_accuracy += accuracy.item()
        total_loss_gen += loss_gen.item()

    # 에폭 평균 계산
    avg_loss_dis = total_loss_dis / batches
    avg_accuracy = total_accuracy / batches
    avg_loss_gen = total_loss_gen / batches

    print(
        f"EPOCH #{epoch}/{EPOCHS}, LOSS(D): {avg_loss_dis:.4f}, ACCURACY(D): {avg_accuracy:.4f}, LOSS(G): {avg_loss_gen:.4f}"
    )

    # 손실, 정확도 기록
    writer.add_scalar("Loss/Discriminator", avg_loss_dis, epoch)
    writer.add_scalar("Loss/Generator", avg_loss_gen, epoch)
    writer.add_scalar("Accuracy/Discriminator", avg_accuracy, epoch)

    # 이미지 기록
    with torch.no_grad():
        fake_images = gan.generate(32)
        img_grid = torchvision.utils.make_grid(fake_images, normalize=True)
        writer.add_image("Generated Images", img_grid, epoch)

    if epoch % 10 == 0:
        torch.save(gan.state_dict(), f"./checkpoints/checkpoint_epoch_{epoch}.pth")

writer.close()
# Out:
# EPOCH #1/100, LOSS(D): 0.1391, ACCURACY(D): 0.9871, LOSS(G): 4.9357
# EPOCH #2/100, LOSS(D): 0.1076, ACCURACY(D): 0.9885, LOSS(G): 5.1475
# EPOCH #3/100, LOSS(D): 0.1574, ACCURACY(D): 0.9817, LOSS(G): 4.9762
# EPOCH #4/100, LOSS(D): 0.1869, ACCURACY(D): 0.9746, LOSS(G): 4.6546
# EPOCH #5/100, LOSS(D): 0.2162, ACCURACY(D): 0.9698, LOSS(G): 4.6126
# EPOCH #6/100, LOSS(D): 0.2300, ACCURACY(D): 0.9682, LOSS(G): 4.5312
# EPOCH #7/100, LOSS(D): 0.3167, ACCURACY(D): 0.9457, LOSS(G): 4.0596
# EPOCH #8/100, LOSS(D): 0.2669, ACCURACY(D): 0.9544, LOSS(G): 4.3297
# EPOCH #9/100, LOSS(D): 0.3344, ACCURACY(D): 0.9381, LOSS(G): 4.0162
# EPOCH #10/100, LOSS(D): 0.3526, ACCURACY(D): 0.9345, LOSS(G): 3.8670
# EPOCH #11/100, LOSS(D): 0.4554, ACCURACY(D): 0.9103, LOSS(G): 3.4568
# EPOCH #12/100, LOSS(D): 0.4345, ACCURACY(D): 0.9125, LOSS(G): 3.4684
# EPOCH #13/100, LOSS(D): 0.5522, ACCURACY(D): 0.8848, LOSS(G): 3.0438
# EPOCH #14/100, LOSS(D): 0.5661, ACCURACY(D): 0.8793, LOSS(G): 2.9363
# EPOCH #15/100, LOSS(D): 0.5984, ACCURACY(D): 0.8723, LOSS(G): 2.8432
# EPOCH #16/100, LOSS(D): 0.6293, ACCURACY(D): 0.8631, LOSS(G): 2.7000
# EPOCH #17/100, LOSS(D): 0.6177, ACCURACY(D): 0.8671, LOSS(G): 2.6825
# EPOCH #18/100, LOSS(D): 0.6361, ACCURACY(D): 0.8625, LOSS(G): 2.6704
# EPOCH #19/100, LOSS(D): 0.6327, ACCURACY(D): 0.8620, LOSS(G): 2.6817
# EPOCH #20/100, LOSS(D): 0.6540, ACCURACY(D): 0.8576, LOSS(G): 2.5462
# EPOCH #21/100, LOSS(D): 0.6428, ACCURACY(D): 0.8603, LOSS(G): 2.6390
# EPOCH #22/100, LOSS(D): 0.6508, ACCURACY(D): 0.8582, LOSS(G): 2.5805
# EPOCH #23/100, LOSS(D): 0.6505, ACCURACY(D): 0.8579, LOSS(G): 2.5580
# EPOCH #24/100, LOSS(D): 0.6363, ACCURACY(D): 0.8634, LOSS(G): 2.5753
# EPOCH #25/100, LOSS(D): 0.6485, ACCURACY(D): 0.8594, LOSS(G): 2.5608
# EPOCH #26/100, LOSS(D): 0.6520, ACCURACY(D): 0.8595, LOSS(G): 2.5520
# EPOCH #27/100, LOSS(D): 0.6319, ACCURACY(D): 0.8643, LOSS(G): 2.5457
# EPOCH #28/100, LOSS(D): 0.6379, ACCURACY(D): 0.8612, LOSS(G): 2.5975
# EPOCH #29/100, LOSS(D): 0.6282, ACCURACY(D): 0.8636, LOSS(G): 2.5648
# EPOCH #30/100, LOSS(D): 0.6500, ACCURACY(D): 0.8582, LOSS(G): 2.5871
# EPOCH #31/100, LOSS(D): 0.6518, ACCURACY(D): 0.8583, LOSS(G): 2.5484
# EPOCH #32/100, LOSS(D): 0.6502, ACCURACY(D): 0.8594, LOSS(G): 2.5186
# EPOCH #33/100, LOSS(D): 0.6640, ACCURACY(D): 0.8567, LOSS(G): 2.5221
# EPOCH #34/100, LOSS(D): 0.6505, ACCURACY(D): 0.8601, LOSS(G): 2.5563
# EPOCH #35/100, LOSS(D): 0.6418, ACCURACY(D): 0.8609, LOSS(G): 2.5277
# EPOCH #36/100, LOSS(D): 0.6579, ACCURACY(D): 0.8575, LOSS(G): 2.5466
# EPOCH #37/100, LOSS(D): 0.6388, ACCURACY(D): 0.8627, LOSS(G): 2.5490
# EPOCH #38/100, LOSS(D): 0.6752, ACCURACY(D): 0.8525, LOSS(G): 2.5025
# EPOCH #39/100, LOSS(D): 0.6620, ACCURACY(D): 0.8570, LOSS(G): 2.5567
# EPOCH #40/100, LOSS(D): 0.6633, ACCURACY(D): 0.8556, LOSS(G): 2.5023
# EPOCH #41/100, LOSS(D): 0.6571, ACCURACY(D): 0.8585, LOSS(G): 2.5034
# EPOCH #42/100, LOSS(D): 0.6695, ACCURACY(D): 0.8537, LOSS(G): 2.4864
# EPOCH #43/100, LOSS(D): 0.6801, ACCURACY(D): 0.8499, LOSS(G): 2.4541
# EPOCH #44/100, LOSS(D): 0.6690, ACCURACY(D): 0.8528, LOSS(G): 2.5075
# EPOCH #45/100, LOSS(D): 0.6436, ACCURACY(D): 0.8607, LOSS(G): 2.4859
# EPOCH #46/100, LOSS(D): 0.6676, ACCURACY(D): 0.8534, LOSS(G): 2.4830
# EPOCH #47/100, LOSS(D): 0.6749, ACCURACY(D): 0.8498, LOSS(G): 2.4787
# EPOCH #48/100, LOSS(D): 0.6919, ACCURACY(D): 0.8463, LOSS(G): 2.4859
# EPOCH #49/100, LOSS(D): 0.6787, ACCURACY(D): 0.8528, LOSS(G): 2.4516
# EPOCH #50/100, LOSS(D): 0.6717, ACCURACY(D): 0.8544, LOSS(G): 2.4603
# EPOCH #51/100, LOSS(D): 0.6912, ACCURACY(D): 0.8480, LOSS(G): 2.4232
# EPOCH #52/100, LOSS(D): 0.7042, ACCURACY(D): 0.8444, LOSS(G): 2.3801
# EPOCH #53/100, LOSS(D): 0.7031, ACCURACY(D): 0.8453, LOSS(G): 2.4212
# EPOCH #54/100, LOSS(D): 0.7104, ACCURACY(D): 0.8426, LOSS(G): 2.3710
# EPOCH #55/100, LOSS(D): 0.7112, ACCURACY(D): 0.8429, LOSS(G): 2.3298
# EPOCH #56/100, LOSS(D): 0.7202, ACCURACY(D): 0.8410, LOSS(G): 2.3077
# EPOCH #57/100, LOSS(D): 0.7148, ACCURACY(D): 0.8422, LOSS(G): 2.3530
# EPOCH #58/100, LOSS(D): 0.7272, ACCURACY(D): 0.8379, LOSS(G): 2.2768
# EPOCH #59/100, LOSS(D): 0.7249, ACCURACY(D): 0.8397, LOSS(G): 2.2807
# EPOCH #60/100, LOSS(D): 0.7192, ACCURACY(D): 0.8412, LOSS(G): 2.3099
# EPOCH #61/100, LOSS(D): 0.7506, ACCURACY(D): 0.8315, LOSS(G): 2.2459
# EPOCH #62/100, LOSS(D): 0.7218, ACCURACY(D): 0.8406, LOSS(G): 2.2348
# EPOCH #63/100, LOSS(D): 0.7338, ACCURACY(D): 0.8372, LOSS(G): 2.2387
# EPOCH #64/100, LOSS(D): 0.7586, ACCURACY(D): 0.8296, LOSS(G): 2.2235
# EPOCH #65/100, LOSS(D): 0.7355, ACCURACY(D): 0.8365, LOSS(G): 2.2204
# EPOCH #66/100, LOSS(D): 0.7598, ACCURACY(D): 0.8297, LOSS(G): 2.2017
# EPOCH #67/100, LOSS(D): 0.7586, ACCURACY(D): 0.8294, LOSS(G): 2.1773
# EPOCH #68/100, LOSS(D): 0.7568, ACCURACY(D): 0.8299, LOSS(G): 2.1548
# EPOCH #69/100, LOSS(D): 0.7679, ACCURACY(D): 0.8270, LOSS(G): 2.1759
# EPOCH #70/100, LOSS(D): 0.7492, ACCURACY(D): 0.8328, LOSS(G): 2.1629
# EPOCH #71/100, LOSS(D): 0.7677, ACCURACY(D): 0.8281, LOSS(G): 2.1634
# EPOCH #72/100, LOSS(D): 0.7758, ACCURACY(D): 0.8253, LOSS(G): 2.1318
# EPOCH #73/100, LOSS(D): 0.7698, ACCURACY(D): 0.8276, LOSS(G): 2.1215
# EPOCH #74/100, LOSS(D): 0.7770, ACCURACY(D): 0.8242, LOSS(G): 2.1315
# EPOCH #75/100, LOSS(D): 0.7704, ACCURACY(D): 0.8280, LOSS(G): 2.0722
# EPOCH #76/100, LOSS(D): 0.7608, ACCURACY(D): 0.8290, LOSS(G): 2.1311
# EPOCH #77/100, LOSS(D): 0.7875, ACCURACY(D): 0.8221, LOSS(G): 2.0827
# EPOCH #78/100, LOSS(D): 0.7638, ACCURACY(D): 0.8276, LOSS(G): 2.0737
# EPOCH #79/100, LOSS(D): 0.7860, ACCURACY(D): 0.8234, LOSS(G): 2.0640
# EPOCH #80/100, LOSS(D): 0.7852, ACCURACY(D): 0.8212, LOSS(G): 2.0619
# EPOCH #81/100, LOSS(D): 0.7952, ACCURACY(D): 0.8204, LOSS(G): 2.0419
# EPOCH #82/100, LOSS(D): 0.7931, ACCURACY(D): 0.8201, LOSS(G): 2.0427
# EPOCH #83/100, LOSS(D): 0.7838, ACCURACY(D): 0.8225, LOSS(G): 2.0264
# EPOCH #84/100, LOSS(D): 0.7927, ACCURACY(D): 0.8206, LOSS(G): 2.0652
# EPOCH #85/100, LOSS(D): 0.7848, ACCURACY(D): 0.8212, LOSS(G): 2.0690
# EPOCH #86/100, LOSS(D): 0.7893, ACCURACY(D): 0.8200, LOSS(G): 2.0524
# EPOCH #87/100, LOSS(D): 0.7909, ACCURACY(D): 0.8223, LOSS(G): 2.0683
# EPOCH #88/100, LOSS(D): 0.7846, ACCURACY(D): 0.8236, LOSS(G): 2.0267
# EPOCH #89/100, LOSS(D): 0.8035, ACCURACY(D): 0.8171, LOSS(G): 2.0335
# EPOCH #90/100, LOSS(D): 0.8023, ACCURACY(D): 0.8191, LOSS(G): 2.0255
# EPOCH #91/100, LOSS(D): 0.7943, ACCURACY(D): 0.8197, LOSS(G): 2.0350
# EPOCH #92/100, LOSS(D): 0.8062, ACCURACY(D): 0.8153, LOSS(G): 2.0137
# EPOCH #93/100, LOSS(D): 0.8004, ACCURACY(D): 0.8172, LOSS(G): 1.9824
# EPOCH #94/100, LOSS(D): 0.7956, ACCURACY(D): 0.8185, LOSS(G): 1.9926
# EPOCH #95/100, LOSS(D): 0.7966, ACCURACY(D): 0.8201, LOSS(G): 2.0020
# EPOCH #96/100, LOSS(D): 0.8183, ACCURACY(D): 0.8139, LOSS(G): 1.9894
# EPOCH #97/100, LOSS(D): 0.8116, ACCURACY(D): 0.8148, LOSS(G): 1.9466
# EPOCH #98/100, LOSS(D): 0.7960, ACCURACY(D): 0.8203, LOSS(G): 1.9530
# EPOCH #99/100, LOSS(D): 0.8011, ACCURACY(D): 0.8187, LOSS(G): 1.9668
# EPOCH #100/100, LOSS(D): 0.8103, ACCURACY(D): 0.8145, LOSS(G): 1.9404

# %%
gan.load_state_dict(torch.load("./checkpoints/checkpoint_epoch_100.pth"))
# Out:
# <All keys matched successfully>
